# %% [markdown]
# # Getting started with forecasting with pretrained ACED-HMM

# %% [markdown]
# This notebook walks through making accurate forecasts using a pretrained ACED-HMM model that was fitted on census counts from Massachusetts between Nov. 11 and Jan. 11.
#
# The users may also try out our other pretrained models by modifying the filepaths in each cell accordingly:
# 1. US/UT-20201111-20210111-20210211\

# %% [markdown]
# # 1. Visualize prior and pretrained posterior distributions over ACED-HMM's parameters

# %%
from aced_hmm.visualize_forecasts import plot_params

# %%
samples_path = 'results/US/MA-20201111-20210111-20210211/PRETRAINED_posterior_samples.json'

## Other default parameters
#
# filename_prior='priors/abc_prior_config_OnCDCTableReasonable.json' --> our prior based on CDC data
# filename_to_save=None --> currently not saving the plot(s)
# filename_true_params=None --> only provided if true parameters are known (used in experiments with synthetic data)
# plot_disjointly=False --> currently plotting the parameters in one big plot, as opposed to each parameter in one plot
#                           If False, then 'filename_to_save' must be a full file path, such as 'MA_parameters.pdf'
#                           If True, then 'filename_to_save' must be just a template, which is then completed by the
#                               code with the parameter name. For example, if specifying 'MA_parameters', the plots are
#                               saved as 'MA_parameters_proba_Recovering_InGeneralWard.pdf', etc.

plot_params(samples_path)

# %% [markdown]
# # 2. Run forecast with pretrained posterior

# %% [markdown]
# The script `run_forecast` runs a single forecast for every sample from the posterior distribution of ACED-HMM parameters. Each forecast is also run with a different random seed, in increasing order from the provided value of random_seed. The user can specify how many samples to consider; providing 'None' uses all the samples.
#
# If `run_forecast` is provided a single value for each parameter, as opposed to a list of samples, the script runs num_seeds forecasts each with the same, provided parameters. If num_seeds is 'None', only one forecast is made.
#
# Notice the 'approximate' argument; it determines how many patients are modeled 'together' (i.e. with a single trajectory). It reduces granularity in the forecasta, but also the runtime. Try decreasing and increasing it: how does the runtime change? how does the uncertainty change in the plots of step 4?

# %% [markdown]
# #### Run this if on Linux / MAC-OS

# %%
# %%bash
# python -m aced_hmm.run_forecast --func_name python \
#                                   --config_path results/US/SD-20201111-20210111-20210211/PRETRAINED_config_after_abc.json \
#                                   --output_dir results/US/SD-20201111-20210111-20210211/individual_forecasts \
#                                   --output_file PRETRAINED_results_after_abc-{{random_seed}}.csv \
#                                   --approximate 5 \
#                                   --random_seed 1001 \
#                                   --num_seeds None
# Out:
# results/US/SD-20201111-20210111-20210211/PRETRAINED_config_after_abc.json
# Forecasting from samples ...
# Using 2000 parameter samples, each with a distinct random seed.
# --------------------------------------------
#            Running 2000 simulations
# --------------------------------------------
# 100%|██████████| 2000/2000 [00:18<00:00, 106.62it/s]

# %% [markdown]
# #### Run this if on Windows

# %%
# %%cmd
# python -m aced_hmm.run_forecast --func_name python ^
#                                   --config_path results/US/MA-20201111-20210111-20210211/PRETRAINED_config_after_abc.json ^
#                                   --output_dir results/US/MA-20201111-20210111-20210211/individual_forecasts ^
#                                   --output_file PRETRAINED_results_after_abc-{{random_seed}}.csv ^
#                                   --approximate 5 ^
#                                   --random_seed 1001 ^
#                                   --num_seeds None
# Out:
# Microsoft Windows [Version 10.0.18363.1440]
# (c) 2019 Microsoft Corporation. All rights reserved.
#
# (aced_hmm) C:\Users\giamm\aced_hmm_original_repo\aced-hmm-hospitalized-patient-trajectory-model>python -m aced_hmm.run_forecast --func_name python ^
# More?                                   --config_path results/US/MA-20201111-20210111-20210211/PRETRAINED_config_after_abc.json ^
# More?                                   --output_dir results/US/MA-20201111-20210111-20210211/individual_forecasts ^
# More?                                   --output_file PRETRAINED_results_after_abc-{{random_seed}}.csv ^
# More?                                   --approximate 5 ^
# More?                                   --random_seed 1001 ^
# More?                                   --num_seeds None
# Forecasting from samples ...
# Using 2000 parameter samples, each with a distinct random seed.
# --------------------------------------------
#            Running 2000 simulations
# --------------------------------------------
#
# (aced_hmm) C:\Users\giamm\aced_hmm_original_repo\aced-hmm-hospitalized-patient-trajectory-model>
# 100%|##########| 2000/2000 [05:25<00:00,  6.14it/s]

# %% [markdown]
# # 3. Summarize forecasts

# %% [markdown]
# #### Run this if on Linux / MAC-OS

# %%
# %%bash
# python -m aced_hmm.summarize_forecasts --input_dir results/US/SD-20201111-20210111-20210211/individual_forecasts \
#                                          --output_dir results/US/SD-20201111-20210111-20210211 \
#                                          --output_template PRETRAINED_summary_after_abc_ \
#                                          --input_csv_file_pattern PRETRAINED_results_after_abc*.csv \
#                                          --comma_sep_percentiles 1,2.5,5,10,25,50,75,90,95,97.5,99
# Out:
# ----------------------------------------
# Reading in data from 2000 simulations
# ----------------------------------------
# 100%|██████████| 2000/2000 [00:00<00:00, 2274.59it/s]
# ----------------------------------------
# Computing summaries for 11 percentiles
# ----------------------------------------

# %% [markdown]
# #### Run this if on Windows

# %%
# %%cmd
# python -m aced_hmm.summarize_forecasts --input_dir results/US/MA-20201111-20210111-20210211/individual_forecasts ^
#                                          --output_dir results/US/MA-20201111-20210111-20210211 ^
#                                          --output_template PRETRAINED_summary_after_abc_ ^
#                                          --input_csv_file_pattern PRETRAINED_results_after_abc*.csv ^
#                                          --comma_sep_percentiles 1,2.5,5,10,25,50,75,90,95,97.5,99
# Out:
# Microsoft Windows [Version 10.0.18363.1440]
# (c) 2019 Microsoft Corporation. All rights reserved.
#
# (aced_hmm) C:\Users\giamm\aced_hmm_original_repo\aced-hmm-hospitalized-patient-trajectory-model>python -m aced_hmm.summarize_forecasts --input_dir results/US/MA-20201111-20210111-20210211/individual_forecasts ^
# More?                                          --output_dir results/US/MA-20201111-20210111-20210211 ^
# More?                                          --output_template PRETRAINED_summary_after_abc_ ^
# More?                                          --input_csv_file_pattern PRETRAINED_results_after_abc*.csv ^
# More?                                          --comma_sep_percentiles 1,2.5,5,10,25,50,75,90,95,97.5,99
# ----------------------------------------
# Reading in data from 2000 simulations
# ----------------------------------------
# ----------------------------------------
# Computing summaries for 11 percentiles
# ----------------------------------------
#
# (aced_hmm) C:\Users\giamm\aced_hmm_original_repo\aced-hmm-hospitalized-patient-trajectory-model>
# 100%|##########| 2000/2000 [00:30<00:00, 65.03it/s]

# %% [markdown]
# # 4. Visualize forecasts

# %% [markdown]
# We can see good fits to the training counts, as well as accurate forecasts during the test window.

# %%
from aced_hmm.visualize_forecasts import plot_forecasts

# %%
config_path = 'results/US/SD-20201111-20210111-20210211/PRETRAINED_config_after_abc.json'
input_summaries_template_path = 'results/US/SD-20201111-20210111-20210211/PRETRAINED_summary_after_abc'
true_stats = 'datasets/US/SD-20201111-20210111-20210211/daily_counts.csv'

## Other default parameters
#
# figure_template_path=None --> currently not saving the plots. Must provide a template, which the code completes with the 
#                                   count name. For example, specifying 'MA_forecasts' saves the plots with names 
#                                   'MA_forecast_n_InGeneralWard.pdf', etc.
# smooth_terminal_counts=True --> plots smoothed version of true terminal counts (n_TERMINAL_5daysSmoothed)
# expected_columns=['n_discharged_InGeneralWard', 'n_InGeneralWard', 'n_OffVentInICU', 'n_OnVentInICU', 'n_InICU', 'n_occupied_beds', 'n_TERMINAL']
#                  --> counts to plot forecasts for

plot_forecasts(input_summaries_template_path, config_path, true_stats)

# %%
import json

with open("./results/US/MA-20201111-20210111-20210211/PRETRAINED_posterior_samples.json", "r") as f:
    posterior_samples = json.load(f)

# %%
# Example analysis
for param_name, values in posterior_samples.items():
    if isinstance(values, list):
        print(f"{param_name}: mean={sum(values)/len(values):.4f}, min={min(values):.4f}, max={max(values):.4f}")
    elif isinstance(values, dict):
        for sub_param, sub_values in values.items():
            if isinstance(sub_values, list):
                print(f"{param_name}.{sub_param}: mean={sum(sub_values)/len(sub_values):.4f}, min={min(sub_values):.4f}, max={max(sub_values):.4f}")
# Out:
# proba_Recovering_given_InGeneralWard: mean=0.6516, min=0.6042, max=0.6836
# proba_Die_after_Declining_InGeneralWard: mean=0.0188, min=0.0036, max=0.0500
# pmf_duration_Recovering_InGeneralWard.1: mean=0.0499, min=0.0000, max=0.1396
# pmf_duration_Recovering_InGeneralWard.2: mean=0.0795, min=0.0000, max=0.1470
# pmf_duration_Recovering_InGeneralWard.3: mean=0.1105, min=0.0047, max=0.1590
# pmf_duration_Recovering_InGeneralWard.4: mean=0.1406, min=0.0805, max=0.2066
# pmf_duration_Recovering_InGeneralWard.5: mean=0.1593, min=0.0891, max=0.3941
# pmf_duration_Recovering_InGeneralWard.6: mean=0.1461, min=0.0792, max=0.3801
# pmf_duration_Recovering_InGeneralWard.7: mean=0.1081, min=0.0676, max=0.2006
# pmf_duration_Recovering_InGeneralWard.8: mean=0.0713, min=0.0147, max=0.0998
# pmf_duration_Recovering_InGeneralWard.9: mean=0.0458, min=0.0011, max=0.0734
# pmf_duration_Recovering_InGeneralWard.10: mean=0.0297, min=0.0000, max=0.0513
# pmf_duration_Recovering_InGeneralWard.11: mean=0.0194, min=0.0000, max=0.0375
# pmf_duration_Recovering_InGeneralWard.12: mean=0.0128, min=0.0000, max=0.0308
# pmf_duration_Recovering_InGeneralWard.13: mean=0.0085, min=0.0000, max=0.0251
# pmf_duration_Recovering_InGeneralWard.14: mean=0.0058, min=0.0000, max=0.0206
# pmf_duration_Recovering_InGeneralWard.15: mean=0.0040, min=0.0000, max=0.0168
# pmf_duration_Recovering_InGeneralWard.16: mean=0.0028, min=0.0000, max=0.0136
# pmf_duration_Recovering_InGeneralWard.17: mean=0.0020, min=0.0000, max=0.0110
# pmf_duration_Recovering_InGeneralWard.18: mean=0.0014, min=0.0000, max=0.0088
# pmf_duration_Recovering_InGeneralWard.19: mean=0.0010, min=0.0000, max=0.0071
# pmf_duration_Recovering_InGeneralWard.20: mean=0.0007, min=0.0000, max=0.0056
# pmf_duration_Recovering_InGeneralWard.21: mean=0.0005, min=0.0000, max=0.0045
# pmf_duration_Recovering_InGeneralWard.22: mean=0.0004, min=0.0000, max=0.0035
# pmf_duration_Recovering_InGeneralWard.lam: mean=3.6294, min=1.1240, max=5.2540
# pmf_duration_Recovering_InGeneralWard.tau: mean=0.2830, min=-0.7146, max=1.0834
# pmf_duration_Declining_InGeneralWard.1: mean=0.1427, min=0.0033, max=0.4073
# pmf_duration_Declining_InGeneralWard.2: mean=0.2592, min=0.0952, max=0.6401
# pmf_duration_Declining_InGeneralWard.3: mean=0.2348, min=0.0528, max=0.4647
# pmf_duration_Declining_InGeneralWard.4: mean=0.1601, min=0.0011, max=0.3493
# pmf_duration_Declining_InGeneralWard.5: mean=0.0937, min=0.0000, max=0.1716
# pmf_duration_Declining_InGeneralWard.6: mean=0.0511, min=0.0000, max=0.1385
# pmf_duration_Declining_InGeneralWard.7: mean=0.0274, min=0.0000, max=0.0977
# pmf_duration_Declining_InGeneralWard.8: mean=0.0146, min=0.0000, max=0.0711
# pmf_duration_Declining_InGeneralWard.9: mean=0.0077, min=0.0000, max=0.0485
# pmf_duration_Declining_InGeneralWard.10: mean=0.0041, min=0.0000, max=0.0312
# pmf_duration_Declining_InGeneralWard.11: mean=0.0021, min=0.0000, max=0.0205
# pmf_duration_Declining_InGeneralWard.12: mean=0.0011, min=0.0000, max=0.0141
# pmf_duration_Declining_InGeneralWard.13: mean=0.0006, min=0.0000, max=0.0095
# pmf_duration_Declining_InGeneralWard.14: mean=0.0003, min=0.0000, max=0.0063
# pmf_duration_Declining_InGeneralWard.15: mean=0.0002, min=0.0000, max=0.0041
# pmf_duration_Declining_InGeneralWard.16: mean=0.0001, min=0.0000, max=0.0026
# pmf_duration_Declining_InGeneralWard.17: mean=0.0001, min=0.0000, max=0.0017
# pmf_duration_Declining_InGeneralWard.18: mean=0.0000, min=0.0000, max=0.0010
# pmf_duration_Declining_InGeneralWard.19: mean=0.0000, min=0.0000, max=0.0006
# pmf_duration_Declining_InGeneralWard.20: mean=0.0000, min=0.0000, max=0.0004
# pmf_duration_Declining_InGeneralWard.21: mean=0.0000, min=0.0000, max=0.0002
# pmf_duration_Declining_InGeneralWard.22: mean=0.0000, min=0.0000, max=0.0001
# pmf_duration_Declining_InGeneralWard.lam: mean=1.9689, min=1.0773, max=3.7522
# pmf_duration_Declining_InGeneralWard.tau: mean=0.0879, min=-0.6133, max=0.6543
# proba_Recovering_given_OffVentInICU: mean=0.2307, min=0.1659, max=0.3129
# proba_Die_after_Declining_OffVentInICU: mean=0.0279, min=0.0040, max=0.0584
# pmf_duration_Recovering_OffVentInICU.1: mean=0.1968, min=0.0001, max=0.4302
# pmf_duration_Recovering_OffVentInICU.2: mean=0.4137, min=0.0730, max=0.9724
# pmf_duration_Recovering_OffVentInICU.3: mean=0.2491, min=0.0061, max=0.7396
# pmf_duration_Recovering_OffVentInICU.4: mean=0.0799, min=0.0000, max=0.2860
# pmf_duration_Recovering_OffVentInICU.5: mean=0.0305, min=0.0000, max=0.1646
# pmf_duration_Recovering_OffVentInICU.6: mean=0.0142, min=0.0000, max=0.1434
# pmf_duration_Recovering_OffVentInICU.7: mean=0.0074, min=0.0000, max=0.1145
# pmf_duration_Recovering_OffVentInICU.8: mean=0.0040, min=0.0000, max=0.0826
# pmf_duration_Recovering_OffVentInICU.9: mean=0.0022, min=0.0000, max=0.0546
# pmf_duration_Recovering_OffVentInICU.10: mean=0.0011, min=0.0000, max=0.0369
# pmf_duration_Recovering_OffVentInICU.11: mean=0.0006, min=0.0000, max=0.0238
# pmf_duration_Recovering_OffVentInICU.12: mean=0.0003, min=0.0000, max=0.0146
# pmf_duration_Recovering_OffVentInICU.13: mean=0.0001, min=0.0000, max=0.0087
# pmf_duration_Recovering_OffVentInICU.14: mean=0.0001, min=0.0000, max=0.0049
# pmf_duration_Recovering_OffVentInICU.15: mean=0.0000, min=0.0000, max=0.0027
# pmf_duration_Recovering_OffVentInICU.16: mean=0.0000, min=0.0000, max=0.0015
# pmf_duration_Recovering_OffVentInICU.17: mean=0.0000, min=0.0000, max=0.0008
# pmf_duration_Recovering_OffVentInICU.18: mean=0.0000, min=0.0000, max=0.0004
# pmf_duration_Recovering_OffVentInICU.19: mean=0.0000, min=0.0000, max=0.0002
# pmf_duration_Recovering_OffVentInICU.20: mean=0.0000, min=0.0000, max=0.0001
# pmf_duration_Recovering_OffVentInICU.21: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Recovering_OffVentInICU.22: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Recovering_OffVentInICU.lam: mean=1.6332, min=1.0079, max=4.2705
# pmf_duration_Recovering_OffVentInICU.tau: mean=-0.3073, min=-1.1248, max=0.4279
# pmf_duration_Declining_OffVentInICU.1: mean=0.2789, min=0.0000, max=0.4843
# pmf_duration_Declining_OffVentInICU.2: mean=0.5306, min=0.3452, max=0.9997
# pmf_duration_Declining_OffVentInICU.3: mean=0.1538, min=0.0000, max=0.3157
# pmf_duration_Declining_OffVentInICU.4: mean=0.0304, min=0.0000, max=0.1425
# pmf_duration_Declining_OffVentInICU.5: mean=0.0052, min=0.0000, max=0.0468
# pmf_duration_Declining_OffVentInICU.6: mean=0.0009, min=0.0000, max=0.0113
# pmf_duration_Declining_OffVentInICU.7: mean=0.0001, min=0.0000, max=0.0025
# pmf_duration_Declining_OffVentInICU.8: mean=0.0000, min=0.0000, max=0.0005
# pmf_duration_Declining_OffVentInICU.9: mean=0.0000, min=0.0000, max=0.0001
# pmf_duration_Declining_OffVentInICU.10: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.11: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.12: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.13: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.14: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.15: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.16: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.17: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.18: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.19: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.20: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.21: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.22: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OffVentInICU.lam: mean=1.2514, min=1.0010, max=1.7713
# pmf_duration_Declining_OffVentInICU.tau: mean=-0.4224, min=-1.5084, max=0.0548
# proba_Recovering_given_OnVentInICU: mean=0.0763, min=0.0236, max=0.1896
# proba_Die_after_Declining_OnVentInICU: mean=1.0000, min=1.0000, max=1.0000
# pmf_duration_Recovering_OnVentInICU.1: mean=0.0126, min=0.0000, max=0.0499
# pmf_duration_Recovering_OnVentInICU.2: mean=0.0211, min=0.0000, max=0.0964
# pmf_duration_Recovering_OnVentInICU.3: mean=0.0320, min=0.0000, max=0.1438
# pmf_duration_Recovering_OnVentInICU.4: mean=0.0446, min=0.0003, max=0.1668
# pmf_duration_Recovering_OnVentInICU.5: mean=0.0572, min=0.0011, max=0.1662
# pmf_duration_Recovering_OnVentInICU.6: mean=0.0674, min=0.0035, max=0.2104
# pmf_duration_Recovering_OnVentInICU.7: mean=0.0737, min=0.0086, max=0.2141
# pmf_duration_Recovering_OnVentInICU.8: mean=0.0760, min=0.0179, max=0.1690
# pmf_duration_Recovering_OnVentInICU.9: mean=0.0751, min=0.0322, max=0.1617
# pmf_duration_Recovering_OnVentInICU.10: mean=0.0722, min=0.0239, max=0.1360
# pmf_duration_Recovering_OnVentInICU.11: mean=0.0681, min=0.0128, max=0.1165
# pmf_duration_Recovering_OnVentInICU.12: mean=0.0633, min=0.0063, max=0.1258
# pmf_duration_Recovering_OnVentInICU.13: mean=0.0579, min=0.0018, max=0.1279
# pmf_duration_Recovering_OnVentInICU.14: mean=0.0521, min=0.0004, max=0.1214
# pmf_duration_Recovering_OnVentInICU.15: mean=0.0462, min=0.0001, max=0.1139
# pmf_duration_Recovering_OnVentInICU.16: mean=0.0402, min=0.0000, max=0.1023
# pmf_duration_Recovering_OnVentInICU.17: mean=0.0345, min=0.0000, max=0.0871
# pmf_duration_Recovering_OnVentInICU.18: mean=0.0292, min=0.0000, max=0.0695
# pmf_duration_Recovering_OnVentInICU.19: mean=0.0246, min=0.0000, max=0.0569
# pmf_duration_Recovering_OnVentInICU.20: mean=0.0205, min=0.0000, max=0.0497
# pmf_duration_Recovering_OnVentInICU.21: mean=0.0171, min=0.0000, max=0.0425
# pmf_duration_Recovering_OnVentInICU.22: mean=0.0143, min=0.0000, max=0.0400
# pmf_duration_Recovering_OnVentInICU.lam: mean=8.9475, min=3.7807, max=13.7857
# pmf_duration_Recovering_OnVentInICU.tau: mean=0.4852, min=-0.2649, max=1.4759
# pmf_duration_Declining_OnVentInICU.1: mean=0.1485, min=0.0121, max=0.2542
# pmf_duration_Declining_OnVentInICU.2: mean=0.2832, min=0.1818, max=0.4957
# pmf_duration_Declining_OnVentInICU.3: mean=0.2691, min=0.1686, max=0.4881
# pmf_duration_Declining_OnVentInICU.4: mean=0.1559, min=0.0434, max=0.2777
# pmf_duration_Declining_OnVentInICU.5: mean=0.0774, min=0.0009, max=0.1428
# pmf_duration_Declining_OnVentInICU.6: mean=0.0362, min=0.0000, max=0.0835
# pmf_duration_Declining_OnVentInICU.7: mean=0.0163, min=0.0000, max=0.0559
# pmf_duration_Declining_OnVentInICU.8: mean=0.0073, min=0.0000, max=0.0375
# pmf_duration_Declining_OnVentInICU.9: mean=0.0033, min=0.0000, max=0.0244
# pmf_duration_Declining_OnVentInICU.10: mean=0.0015, min=0.0000, max=0.0153
# pmf_duration_Declining_OnVentInICU.11: mean=0.0007, min=0.0000, max=0.0094
# pmf_duration_Declining_OnVentInICU.12: mean=0.0003, min=0.0000, max=0.0056
# pmf_duration_Declining_OnVentInICU.13: mean=0.0002, min=0.0000, max=0.0033
# pmf_duration_Declining_OnVentInICU.14: mean=0.0001, min=0.0000, max=0.0019
# pmf_duration_Declining_OnVentInICU.15: mean=0.0000, min=0.0000, max=0.0011
# pmf_duration_Declining_OnVentInICU.16: mean=0.0000, min=0.0000, max=0.0006
# pmf_duration_Declining_OnVentInICU.17: mean=0.0000, min=0.0000, max=0.0003
# pmf_duration_Declining_OnVentInICU.18: mean=0.0000, min=0.0000, max=0.0002
# pmf_duration_Declining_OnVentInICU.19: mean=0.0000, min=0.0000, max=0.0001
# pmf_duration_Declining_OnVentInICU.20: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OnVentInICU.21: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OnVentInICU.22: mean=0.0000, min=0.0000, max=0.0000
# pmf_duration_Declining_OnVentInICU.lam: mean=1.8095, min=1.1518, max=2.6854
# pmf_duration_Declining_OnVentInICU.tau: mean=0.0315, min=-0.7408, max=0.5889

# %%
import matplotlib.pyplot as plt
import numpy as np

# For a few key parameters
key_params = ['proba_Recovering_given_InGeneralWard', 'proba_Die_after_Declining_InGeneralWard']
for param in key_params:
    if param in posterior_samples and isinstance(posterior_samples[param], list):
        plt.figure(figsize=(10, 5))
        plt.hist(posterior_samples[param], bins=30, alpha=0.7)
        plt.title(f"Distribution of {param}")
        plt.xlabel("Value")
        plt.ylabel("Frequency")
        plt.axvline(np.mean(posterior_samples[param]), color='red', linestyle='dashed', linewidth=2)
        plt.show()

# %%
# Example: Create a config using mean values
config_dict = {}
for param_name, values in posterior_samples.items():
    if isinstance(values, list):
        config_dict[param_name] = sum(values)/len(values)
    elif isinstance(values, dict):
        config_dict[param_name] = {}
        for sub_param, sub_values in values.items():
            if isinstance(sub_values, list):
                config_dict[param_name][sub_param] = sum(sub_values)/len(sub_values)
